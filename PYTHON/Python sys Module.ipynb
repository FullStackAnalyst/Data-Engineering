# %%
import sys

# %%
# argv	List of command-line arguments passed to the script.
print(sys.argv)
# Out:
# ['C:\\Users\\arsic\\AppData\\Roaming\\Python\\Python314\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\arsic\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3d10f74ed0e424630fa4e68e82e227afa668d0e8d.json']

# %%
# builtin_module_names	Tuple of names of modules compiled into this Python interpreter.
print(sys.builtin_module_names)
# Out:
# ('_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_hmac', '_imp', '_interpchannels', '_interpqueues', '_interpreters', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha2', '_sha3', '_signal', '_sre', '_stat', '_statistics', '_string', '_struct', '_suggestions', '_symtable', '_sysconfig', '_thread', '_tokenize', '_tracemalloc', '_types', '_typing', '_warnings', '_weakref', '_winapi', 'array', 'atexit', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'sys', 'time', 'winreg', 'xxsubtype', 'zlib')

# %%
# byteorder	Native byte order ('big' or 'little').
print(sys.byteorder)
# Out:
# little

# %%
# copyright	Copyright information for the Python interpreter.
print(sys.copyright)
# Out:
# Copyright (c) 2001 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved.

# %%
# exc_info()	Return information about the currently handled exception.
print(sys.exc_info())
# Out:
# (None, None, None)

# %%
# exec_prefix	Prefix for platform-dependent Python files.
print(sys.exec_prefix)
# Out:
# c:\Program Files\Python314

# %%
# executable	Absolute path of the Python interpreter executable.
print(sys.executable)
# Out:
# c:\Program Files\Python314\python.exe

# %%
# flags	Named tuple of command-line flags.
print(sys.flags)
# Out:
# sys.flags(debug=0, inspect=0, interactive=0, optimize=0, dont_write_bytecode=0, no_user_site=0, no_site=0, ignore_environment=0, verbose=0, bytes_warning=0, quiet=0, hash_randomization=1, isolated=0, dev_mode=False, utf8_mode=0, warn_default_encoding=0, safe_path=False, int_max_str_digits=4300)

# %%
# getdefaultencoding()	Return the default string encoding.
print(sys.getdefaultencoding())
# Out:
# utf-8

# %%
# getrecursionlimit()	Return the current recursion limit.
print(sys.getrecursionlimit())
# Out:
# 3000

# %%
# getsizeof()	Return the size of an object in bytes.
print(sys.getsizeof(1))
# Out:
# 28

# %%
# implementation	Object with information about the Python implementation.
print(sys.implementation)
# Out:
# namespace(name='cpython', cache_tag='cpython-314', version=sys.version_info(major=3, minor=14, micro=5, releaselevel='final', serial=0), hexversion=51250672, supports_isolated_interpreters=True)

# %%
# maxsize	Maximum value a variable of type Py_ssize_t can take.
print(sys.maxsize)
# Out:
# 9223372036854775807

# %%
# modules	Dictionary mapping module names to loaded modules.
print(sys.modules)
# Out:
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module '_frozen_importlib' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, 'winreg': <module 'winreg' (built-in)>, '_io': <module '_io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'nt': <module 'nt' (built-in)>, '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>, 'time': <module 'time' (built-in)>, 'zipimport': <module 'zipimport' (frozen)>, '_codecs': <module '_codecs' (built-in)>, 'codecs': <module 'codecs' (frozen)>, 'encodings.aliases': <module 'encodings.aliases' from 'c:\\Program Files\\Python314\\Lib\\encodings\\aliases.py'>, 'encodings._win_cp_codecs': <module 'encodings._win_cp_codecs' from 'c:\\Program Files\\Python314\\Lib\\encodings\\_win_cp_codecs.py'>, 'encodings': <module 'encodings' from 'c:\\Program Files\\Python314\\Lib\\encodings\\__init__.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from 'c:\\Program Files\\Python314\\Lib\\encodings\\utf_8.py'>, '_signal': <module '_signal' (built-in)>, '__main__': <module '__main__'>, '_abc': <module '_abc' (built-in)>, 'abc': <module 'abc' (frozen)>, '_stat': <module '_stat' (built-in)>, 'stat': <module 'stat' (frozen)>, '_collections_abc': <module '_collections_abc' (frozen)>, 'genericpath': <module 'genericpath' (frozen)>, '_winapi': <module '_winapi' (built-in)>, 'ntpath': <module 'ntpath' (frozen)>, 'os.path': <module 'ntpath' (frozen)>, 'os': <module 'os' (frozen)>, '_sitebuiltins': <module '_sitebuiltins' (frozen)>, 'errno': <module 'errno' (built-in)>, 'site': <module 'site' (frozen)>, 'importlib._bootstrap': <module '_frozen_importlib' (frozen)>, 'importlib._bootstrap_external': <module '_frozen_importlib_external' (frozen)>, 'importlib': <module 'importlib' from 'c:\\Program Files\\Python314\\Lib\\importlib\\__init__.py'>, 'importlib.machinery': <module 'importlib.machinery' (frozen)>, 'importlib._abc': <module 'importlib._abc' from 'c:\\Program Files\\Python314\\Lib\\importlib\\_abc.py'>, '_types': <module '_types' (built-in)>, 'types': <module 'types' from 'c:\\Program Files\\Python314\\Lib\\types.py'>, 'importlib.util': <module 'importlib.util' (frozen)>, 'io': <module 'io' (frozen)>, 'runpy': <module 'runpy' (frozen)>, '_operator': <module '_operator' (built-in)>, 'operator': <module 'operator' from 'c:\\Program Files\\Python314\\Lib\\operator.py'>, 'posixpath': <module 'posixpath' (frozen)>, 'collections.abc': <module '_collections_abc' (frozen)>, 'itertools': <module 'itertools' (built-in)>, 'keyword': <module 'keyword' from 'c:\\Program Files\\Python314\\Lib\\keyword.py'>, 'reprlib': <module 'reprlib' from 'c:\\Program Files\\Python314\\Lib\\reprlib.py'>, '_collections': <module '_collections' (built-in)>, 'collections': <module 'collections' from 'c:\\Program Files\\Python314\\Lib\\collections\\__init__.py'>, '_functools': <module '_functools' (built-in)>, 'functools': <module 'functools' from 'c:\\Program Files\\Python314\\Lib\\functools.py'>, 'contextlib': <module 'contextlib' from 'c:\\Program Files\\Python314\\Lib\\contextlib.py'>, 'enum': <module 'enum' from 'c:\\Program Files\\Python314\\Lib\\enum.py'>, '_sre': <module '_sre' (built-in)>, 're._constants': <module 're._constants' from 'c:\\Program Files\\Python314\\Lib\\re\\_constants.py'>, 're._parser': <module 're._parser' from 'c:\\Program Files\\Python314\\Lib\\re\\_parser.py'>, 're._casefix': <module 're._casefix' from 'c:\\Program Files\\Python314\\Lib\\re\\_casefix.py'>, 're._compiler': <module 're._compiler' from 'c:\\Program Files\\Python314\\Lib\\re\\_compiler.py'>, 'copyreg': <module 'copyreg' from 'c:\\Program Files\\Python314\\Lib\\copyreg.py'>, 're': <module 're' from 'c:\\Program Files\\Python314\\Lib\\re\\__init__.py'>, 'fnmatch': <module 'fnmatch' from 'c:\\Program Files\\Python314\\Lib\\fnmatch.py'>, 'glob': <mod ...

# %%
# path	List of strings that specifies the search path for modules.
print(sys.path)
# Out:
# ['c:\\Program Files\\Python314\\python314.zip', 'c:\\Program Files\\Python314\\DLLs', 'c:\\Program Files\\Python314\\Lib', 'c:\\Program Files\\Python314', '', 'C:\\Users\\arsic\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Program Files\\Python314\\Lib\\site-packages']

# %%
# platform	Platform identifier string (e.g., 'win32', 'linux').
print(sys.platform)
# Out:
# win32

# %%
# prefix	Prefix for platform-independent Python files.
print(sys.prefix)
# Out:
# c:\Program Files\Python314

# %%
# setrecursionlimit()	Set the maximum recursion depth.
print(sys.setrecursionlimit(100))
# Out:
# None

# %%
# stderr	Standard error stream (file object).
print(sys.stderr)
# Out:
# <ipykernel.iostream.OutStream object at 0x0000022EFB9C2860>

# %%
# stdin	Standard input stream (file object).
print(sys.stdin)
# Out:
# <_io.TextIOWrapper name='<stdin>' mode='r' encoding='utf-8'>

# %%
# stdout	Standard output stream (file object).
print(sys.stdout)
# Out:
# <ipykernel.iostream.OutStream object at 0x0000022EFB9C2680>

# %%
# version	Python version as a string.
print(sys.version)
# Out:
# 3.14.5 (tags/v3.14.5:5607950, May 10 2026, 10:43:50) [MSC v.1944 64 bit (AMD64)]

# %%
# version_info	Python version as a named tuple.
print(sys.version_info)
# Out:
# sys.version_info(major=3, minor=14, micro=5, releaselevel='final', serial=0)

# %%
# exit()	Exit the program with a given status (default 0).
print(sys.exit)
# Out:
# <built-in function exit>
